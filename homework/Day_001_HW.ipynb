# %%
#[作業1]
import numpy as np
import matplotlib.pyplot as plt
import math

w = 3
b = 0.5

x_lin = np.linspace(0,100,101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y , 'b.' ,label='data points')
plt.title("Assume we have data points")
#legend位置
plt.legend(loc=2)
plt.show()

y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
#%s,%r,%d分別表示字符串以str（），rper(),以及十進制整數表示，%f表示結果為浮點型
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 181.995

# %%
[作業2]
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

PUBG Finish Placement Prediction
1.你選的這組資料為何重要?
想預測遊戲最後生存者為誰

2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
Competitions中有提供資校訓練集
-File descriptions
-Data fields
-Data Sources
sample_submission_V2.csv
test_V2.csv
train_V2.csv

3.蒐集而來的資料型態為何

4.這組資料想解決的問題如何評估
利用特徵工程找尋有效的數據指數

# %%
[作業3]
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
提升業績：平均載客營收增加
你的假設：計算目前平均每小時載客營收，目標提升單位小時內營收數

2資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
資料可能會對你想問的問題產生影響：遇到非用電子消費的乘客會影響紀錄
資料如何蒐集：改用電子收費紀錄，利用時間搓計，記錄單位小時內營收

3蒐集而來的資料型態為何

4你要回答的問題，其如何評估 (tips：你的假設如何驗證)
比較期間內單位營收是否增加
